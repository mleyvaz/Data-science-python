# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/Data-science-python/blob/master/Diagrama_de_clases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Astronaut:
    firstname: str
    lastname: str

    def say_hello(self, name: str) -> str:
        pass

# %% [markdown]
# ![image.png](data:image/png;base64,...)
